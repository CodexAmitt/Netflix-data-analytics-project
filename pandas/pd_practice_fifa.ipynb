# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'fifa.csv')

# %%
df
# Out:
#    player_id        player_name  age
# 0     P00055         Rodri Fati   26
# 1     P00070    Ansu Le Normand   19
# 2     P00066         Gavi Ramos   18
# 3     P00073      Pedro Cubarsi   20
# 4     P00059   Alvaro Oyarzabal   23
# 5     P00072          Dani Gavi   21
# 6     P00058      Rodri Laporte   27
# 7     P00078          Ansu Fati   27
# 8     P00056       Pedro Torres   24
# 9     P00074    Gavi Le Normand   25
# 10    P00069     Ferran Cubarsi   24
# 11    P00071        Marco Mikel   18
# 12    P00076        Alvaro Gavi   28
# 13    P00067       Rodri Alonso   25
# 14    P00057       Gavi Asensio   22
# 15    P00062     Marco Carvajal   33
# 16    P00077      Ferran Morata   26
# 17    P00064      Aymeric Yamal   27
# 18    P00061          Ansu Alba   28
# 19    P00068    Alvaro Llorente   19
# 20    P00060         Ferran Pau   35
# 21    P00075        Rodri Mikel   25
# 22    P00063        Dani Garcia   28
# 23    P00065     Pedro Riquelme   24
# ...

# %%
# show top 5 row
df.head()
# Out:
#   player_id       player_name  age
# 0    P00055        Rodri Fati   26
# 1    P00070   Ansu Le Normand   19
# 2    P00066        Gavi Ramos   18
# 3    P00073     Pedro Cubarsi   20
# 4    P00059  Alvaro Oyarzabal   23

# %%
df.loc[1]['age']
# Out:
# np.int64(19)

# %%
# which player has the highest age
df[df['age'] == df['age'].max()]
# Out:
#    player_id player_name  age
# 26    P01225  Lyle Mvala   38
